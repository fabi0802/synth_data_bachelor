# %%
import pandas as pd
from maerkte import kmeans_cluster_maerkte, synth_maerkte, synth_maerkte_custom
from bestellungen import kmeans_cluster_bestellungen, synth_bestellungen, synth_bestellungen_custom
from bestellpositionen import synth_bestellpositionen
from resampling import resampling_hochrechnung, resampling_maerkte, resampling_bestellungen
from analyse import korrelation_maerkte, korrelation_bestellungen

df = pd.read_parquet('C:/Users/fabik/OneDrive/Projekte/a_synth_data_bachelor/data/raw/orderlines_dezember.parquet')

# %% [markdown]
# ## Test auf Marktebene

# %% [markdown]
# ### Marktcluster

# %%
df_maerkte = df.copy()

df_maerkte = kmeans_cluster_maerkte(df_maerkte)

df_maerkte
# Out:
#      Marktnummer  diff_article  avg_kolli  orders  cluster
# 0       44400003          7966   1.470810      20        1
# 1       44400005          9676   1.408069      21        1
# 2       44400017          4587   1.337268      11        2
# 3       44400019          1187   1.224039       1        0
# 4       44400021          6233   1.349910       8        2
# ..           ...           ...        ...     ...      ...
# 404     69630657             9   1.777778       3        0
# 405     69630913            10   1.900000       2        0
# 406     69630927            14   9.357143       2        0
# 407     69630960            10   1.882353       4        0
# 408     83210412          1135   1.307238      10        0
#
# [409 rows x 5 columns]

# %% [markdown]
# ### Marktgenerierung

# %%
marktmix = {
    0: 0.1,
    1: 0.6,
    2: 0.3
}

maerkte_neu = synth_maerkte(df_maerkte, 409)

maerkte_neu
# Out:
#      Marktnummer  diff_article  avg_kolli  orders  cluster
# 0              1          6995   1.495546      20        1
# 1              2          4769   1.388292      15        1
# 2              3         10718   1.599388      23        1
# 3              4         10898   1.750989      20        1
# 4              5          3253   1.120765      14        1
# ..           ...           ...        ...     ...      ...
# 404          405          1690   1.000000       5        0
# 405          406           601  19.895675       3        0
# 406          407           427   1.000000       8        0
# 407          408           116   5.474928       2        0
# 408          409          1227   8.162088      10        0
#
# [409 rows x 5 columns]

# %% [markdown]
# ## Test auf Bestellebene

# %% [markdown]
# ### Bestellcluster

# %%
df_bestellungen = df.copy()

df_bestellungen = kmeans_cluster_bestellungen(df_bestellungen)

df_bestellungen
# Out:
#       order_id  Marktnummer       Datum  Wochentag  orderlines  \
# 0            0     44400003  2024-12-02          0         791
# 1            1     44400003  2024-12-03          1         919
# 2            2     44400003  2024-12-04          2        1388
# 3            3     44400003  2024-12-05          3         954
# 4            4     44400003  2024-12-06          4         971
# ...        ...          ...         ...        ...         ...
# 3806      3806     83210412  2024-12-16          0         142
# 3807      3807     83210412  2024-12-18          2         156
# 3808      3808     83210412  2024-12-23          0          94
# 3809      3809     83210412  2024-12-27          4         182
# 3810      3810     83210412  2024-12-30          0         114
#
#       diff_sortimente  cluster
# 0                 100        0
# 1                 100        0
# 2                 100        0
# 3                 100        0
# 4                 100        0
# ...               ...      ...
# 3806               73        0
# 3807               79        0
# 3808               57        1
# 3809               86        0
# 3810               67        0
#
# [3811 rows x 7 columns]

# %% [markdown]
# ### Bestellgenerierung

# %%
bestellmix = {
  0: {0: 0.2, 1: 0.8},
  1: {0: 0.4, 1: 0.6},
  2: {0: 0.1, 1: 0.9}
}

bestellungen_neu = synth_bestellungen(df_bestellungen, df_maerkte, maerkte_neu)

bestellungen_neu
# Out:
#       Wochentag  orderlines  diff_sortimente       Datum  Marktnummer  \
# 0             4         532               93  2024-12-19          1.0
# 1             2         547               90  2024-12-28          1.0
# 2             4          47               72  2024-12-06          1.0
# 3             2         659               98  2024-12-09          1.0
# 4             1        1230              102  2024-12-04          1.0
# ...         ...         ...              ...         ...          ...
# 3723          2        1032              101  2024-12-24        409.0
# 3724          5         406              101  2024-12-18        409.0
# 3725          5        1625              102  2024-12-12        409.0
# 3726          4          11               10  2024-12-09        409.0
# 3727          5         119               63  2024-12-06        409.0
#
#       cluster_bestellungen  cluster_markt  order_id
# 0                        0            1.0         1
# 1                        0            1.0         2
# 2                        0            1.0         3
# 3                        0            1.0         4
# 4                        0            1.0         5
# ...                    ...            ...       ...
# 3723                     0            0.0      3724
# 3724                     0            0.0      3725
# 3725                     0            0.0      3726
# 3726                     1            0.0      3727
# 3727                     1            0.0      3728
#
# [3728 rows x 8 columns]

# %% [markdown]
# ## Test auf Bestellpositionseben

# %% [markdown]
# ### Bestellpositionen generieren

# %%
positionen_neu = synth_bestellpositionen(df,df_bestellungen, bestellungen_neu)

positionen_neu
# Out:
#          order_id  Marktnummer      Datum  cluster_bestellungen Sortiment  \
# 0               1          1.0 2024-12-19                     0        81
# 1               1          1.0 2024-12-19                     0        81
# 2               1          1.0 2024-12-19                     0        81
# 3               1          1.0 2024-12-19                     0        81
# 4               1          1.0 2024-12-19                     0        81
# ...           ...          ...        ...                   ...       ...
# 2614856      3728        409.0 2024-12-06                     1        41
# 2614857      3728        409.0 2024-12-06                     1        09
# 2614858      3728        409.0 2024-12-06                     1        10
# 2614859      3728        409.0 2024-12-06                     1        12
# 2614860      3728        409.0 2024-12-06                     1        65
#
#         Artikelnummer  MengeInKolli
# 0        7781418 0006             3
# 1        0281654 0003             1
# 2        0481157 0010             1
# 3        2181365 0006             1
# 4        8181421 0012             1
# ...               ...           ...
# 2614856  1941004 0012             1
# 2614857  8109111 0005             1
# 2614858  7210291 0006             2
# 2614859  9012167 0006             1
# 2614860  7865233 0004             1
#
# [2614861 rows x 7 columns]

# %% [markdown]
# # Test auf Resampling

# %%
df_resampling = resampling_hochrechnung(df, 100)

df_resampling
# Out:
#         Marktnummer  quell_markt  cluster       Datum  Lager Aktion  \
# 0                 1     44652374        0  2024-12-21    151      A
# 1                 1     44652374        0  2024-12-30    151
# 2                 1     44652374        0  2024-12-19    151      A
# 3                 1     44652374        0  2024-12-10    151      A
# 4                 1     44652374        0  2024-12-10    151
# ...             ...          ...      ...         ...    ...    ...
# 623017          100     44652515        1  2024-12-06    500
# 623018          100     44652515        1  2024-12-06    500      A
# 623019          100     44652515        1  2024-12-03    507      A
# 623020          100     44652515        1  2024-12-03    507      A
# 623021          100     44652515        1  2024-12-03    507
#
#        Artikelnummer  MengeInKolli          Markierung Sortiment
# 0       7157380 0006             1            regional        TS
# 1       6038883 0006             1            regional        TS
# 2       4676050 0006             3            regional        TS
# 3       6730531 0004             2            regional        TS
# 4       4676050 0006             2            regional        TS
# ...              ...           ...                 ...       ...
# 623017  0185757 0004             1  Crossdock national        TS
# 623018  0703289 0024             2  Crossdock national        TS
# 623019  8876778 0012             2  Crossdock national        TS
# 623020  3245701 0006             2  Crossdock national        TS
# 623021  8114340 0014             1  Crossdock national        TS
#
# [623022 rows x 10 columns]

# %%
df_resampling_maerkte = resampling_maerkte(df_resampling)

df_resampling_maerkte
# Out:
#     Marktnummer  cluster  diff_article  avg_kolli  orders
# 0             1        0           554   1.464700       8
# 1             2        0           303   2.224026       4
# 2             3        0            21   1.380952       1
# 3             4        0           819   1.202820       7
# 4             5        0            93   2.361702       1
# ..          ...      ...           ...        ...     ...
# 95           96        1          6062   1.523605      19
# 96           97        1          6749   1.946867      19
# 97           98        1         10224   1.462787      18
# 98           99        1          5490   1.752779      16
# 99          100        1          6394   1.296644      16
#
# [100 rows x 5 columns]

# %%
df_resampling_bestellungen = resampling_bestellungen(df_resampling)

df_resampling_bestellungen
# Out:
#      order_id  Marktnummer       Datum  Wochentag  orderlines  diff_sortimente
# 0           0            1  2024-12-03          1          78               55
# 1           1            1  2024-12-06          4         133               76
# 2           2            1  2024-12-10          1         124               68
# 3           3            1  2024-12-13          4         153               81
# 4           4            1  2024-12-16          0         112               62
# ..        ...          ...         ...        ...         ...              ...
# 918       918          100  2024-12-19          3         596              100
# 919       919          100  2024-12-20          4        1041              100
# 920       920          100  2024-12-21          5         618              100
# 921       921          100  2024-12-27          4        1419              100
# 922       922          100  2024-12-30          0         593              100
#
# [923 rows x 6 columns]

# %%
df_corr_maerkte = korrelation_maerkte(df_maerkte, maerkte_neu, df_resampling_maerkte)

df_corr_maerkte
# Out:
#   dataset  mean_abs_delta  max_abs_delta
# 0   synth        0.022906       0.061070
# 1  resamp        0.089945       0.295094

# %%
df_corr_bestellungen = korrelation_bestellungen(df_bestellungen, bestellungen_neu, df_resampling_bestellungen)

df_corr_bestellungen
# Out:
#   dataset  mean_abs_delta  max_abs_delta
# 0   synth        0.010777       0.023134
# 1  resamp        0.004730       0.015674
